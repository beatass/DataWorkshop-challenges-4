# %%
import pandas as pd

from gensim.utils import simple_preprocess
from gensim.models import Doc2Vec
from gensim.models.doc2vec import TaggedDocument
from gensim.models.phrases import Phraser, Phrases

# %%
cd 'drive/My Drive/Colab Notebooks/dw_challenges/dw_four/data'
# Out:
# /content/drive/My Drive/Colab Notebooks/dw_challenges/dw_four/data

# %%
df = pd.read_csv('job_ofer.csv')
df.shape
# Out:
# (36109, 8)

# %%
df.head()
# Out:
#                                         title  ...                           industries
# 0                   Machine Learning Engineer  ...  Information Technology and Services
# 1  Deep Learning Applied Researcher - Chicago  ...  Information Technology and Services
# 2                   Machine Learning Engineer  ...  Information Technology and Services
# 3           Machine Learning / Data Scientist  ...  Information Technology and Services
# 4                             Cloud Architect  ...  Information Technology and Services
#
# [5 rows x 8 columns]

# %%
title_corpus = df['title'].map( simple_preprocess)

# %%
title_corpus
# Out:
# 0                            [machine, learning, engineer]
# 1           [deep, learning, applied, researcher, chicago]
# 2                            [machine, learning, engineer]
# 3                     [machine, learning, data, scientist]
# 4                                       [cloud, architect]
#                                ...
# 36104    [cdl, drivers, hauling, to, canada, no, touch,...
# 36105    [research, scientist, human, computer, interac...
# 36106    [clinical, post, market, surveillance, special...
# 36107    [excellent, teaching, opportunity, in, china, ...
# 36108                [assistant, director, talent, culure]
# Name: title, Length: 36109, dtype: object

# %%
#title_tagged numbers the word after the word in the title_corpus
title_tagged = [TaggedDocument(words=sent, tags=[i]) for i, sent in enumerate(title_corpus)]

# %%
#we check how it works
title_tagged
# Out:
# [TaggedDocument(words=['machine', 'learning', 'engineer'], tags=[0]),
#  TaggedDocument(words=['deep', 'learning', 'applied', 'researcher', 'chicago'], tags=[1]),
#  TaggedDocument(words=['machine', 'learning', 'engineer'], tags=[2]),
#  TaggedDocument(words=['machine', 'learning', 'data', 'scientist'], tags=[3]),
#  TaggedDocument(words=['cloud', 'architect'], tags=[4]),
#  TaggedDocument(words=['data', 'scientist'], tags=[5]),
#  TaggedDocument(words=['store', 'room', 'clerk'], tags=[6]),
#  TaggedDocument(words=['director', 'of', 'product', 'us'], tags=[7]),
#  TaggedDocument(words=['recruiting', 'manager', 'ad', 'census', 'ext', 'gb'], tags=[8]),
#  TaggedDocument(words=['bilingual', 'engineer', 'german', 'germany', 'or', 'switzerland'], tags=[9]),
#  TaggedDocument(words=['sommelier'], tags=[10]),
#  TaggedDocument(words=['entry', 'level', 'project', 'manager', 'shelton', 'ct', 'based'], tags=[11]),
# ...

# %%
title_model = Doc2Vec(vector_size=300, window_size=2, min_count=1)
title_model.build_vocab(title_tagged) #it builds a dictionary for us

# %%
# %time title_model.train(title_tagged, total_examples=title_model.corpus_count, epochs=10)
# Out:
# CPU times: user 38.5 s, sys: 9.77 s, total: 48.3 s
# Wall time: 35 s

# %%
title_model.docvecs.most_similar(0)
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [(21627, 0.8891406059265137),
#  (26386, 0.8817672729492188),
#  (15294, 0.8736801147460938),
#  (388, 0.8711674809455872),
#  (1119, 0.8688223361968994),
#  (15293, 0.8660966157913208),
#  (16256, 0.8623550534248352),
#  (7292, 0.8611762523651123),
#  (15295, 0.8610434532165527),
#  (3685, 0.8578777313232422)]

# %%
df[df.index == 0].title
# Out:
# 0    Machine Learning Engineer
# Name: title, dtype: object

# %%
df[df.index == 34405].title
# Out:
# 34405    Application Engineer - Electrical
# Name: title, dtype: object

# %%
df[df.index == 15294].title
# Out:
# 15294    Machine Shop Manufacturing Process Improvement...
# Name: title, dtype: object

# %%
df[df.index == 21627].title
# Out:
# 21627    JPC - 1177 - Machine Learning Engineer - New York
# Name: title, dtype: object

# %%
df[df.index == 3685].title
# Out:
# 3685    Observability - Integrations Engineer (Go)
# Name: title, dtype: object
